# %%
print('twelveth')
# Out:
# twelveth

# %%
# python 수치해석 라이브러리
import numpy as np

# 회귀 분석용 테스트 데이터 만들어주는 라이브러리
from sklearn.datasets import make_regression

X, y = make_regression(
    n_samples = 500,
    n_features = 2,
    n_informative = 2, # default=10, y=ax+b라고 봤을 때 Control할 수 있는 요소가 2개이다.
    noise = 5
)

print(X.shape)
print(y.shape)
# Out:
# (500, 2)
# (500,)

# %%
print("Output range = [%f %f]"%(min(y), max(y)))
# Out:
# Output range = [-293.681638 282.400125]

# %%
# pip install keras
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
def model_build():
    model = Sequential()
    
    model.add(Dense(16, input_dim=2, activation='relu'))
    model.add(Dense(8, activation='relu'))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %%
# 회귀분석 생성기
from keras.wrappers.scikit_learn import KerasRegressor

# %%
YourModel = KerasRegressor(
    build_fn=model_build,
    epochs=400,
    batch_size=10,
    verbose=1
)

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=5)

# %%
from sklearn.model_selection import cross_val_score

results = cross_val_score(YourModel, X, y, cv=kf)
# Out:
# Epoch 1/400
# 40/40 [==============================] - 0s 954us/step - loss: 9415.5498
# Epoch 2/400
# 40/40 [==============================] - 0s 496us/step - loss: 9403.6377
# Epoch 3/400
# 40/40 [==============================] - 0s 730us/step - loss: 9391.1338
# Epoch 4/400
# 40/40 [==============================] - 0s 787us/step - loss: 9375.6436
# Epoch 5/400
# 40/40 [==============================] - 0s 926us/step - loss: 9357.4434
# Epoch 6/400
# 40/40 [==============================] - 0s 871us/step - loss: 9334.9014
# Epoch 7/400
# 40/40 [==============================] - 0s 845us/step - loss: 9308.9502
# Epoch 8/400
# 40/40 [==============================] - 0s 921us/step - loss: 9276.3340
# Epoch 9/400
# 40/40 [==============================] - 0s 874us/step - loss: 9231.4678
# Epoch 10/400
# 40/40 [==============================] - 0s 836us/step - loss: 9177.4180
# Epoch 11/400
# 40/40 [==============================] - 0s 888us/step - loss: 9115.7852
# Epoch 12/400
# ...

# %%
print("Final Cross Validation Loss:", abs(results.mean()))
# Out:
# Final Cross Validation Loss: 5113.351953125

# %%
import pandas as pd

X = pd.read_csv(
    "./Applied-Deep-Learning-with-Keras/Lesson02/bank_data_feats.csv",
    index_col = 0
)
y = pd.read_csv(
    "./Applied-Deep-Learning-with-Keras/Lesson02/bank_data_target.csv",
    index_col = 0
)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0
)

# %%
seed = 1
np.random.seed(seed)

# %%
print(X.shape)
# Out:
# (4521, 32)

# %%
model = Sequential()
model.add(Dense(8, input_dim=32, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    loss = 'binary_crossentropy',
    optimizer = 'sgd',
    metrics = ['accuracy']
)

# %%
trainRes = model.fit(
    X_train, y_train, 
    batch_size=10, 
    epochs=400, 
    validation_data=(X_test, y_test), 
    verbose=0
)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['figure.figsize']=(6.0, 4.0)
plt.plot(trainRes.history['loss'])
plt.plot(trainRes.history['val_loss'])
plt.ylim(0, 1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test lss'], loc='upper right')

print(
    "Best Accuracy", max(trainRes.history['val_accuracy'])
)
# Out:
# Best Accuracy 0.8784082531929016

# %%
from keras.regularizers import l2

model = Sequential()
# 실질적으로 노이즈는 학습하지 않게 만들어주며, 동시에 반응성도 같이 올력주는 역할 수행 (정규화 과정 !)
model.add(Dense(16, input_dim=32, activation='tanh', kernel_regularizer=l2(0.01)))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='tanh'))
model.add(Dense(4, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    loss='binary_crossentropy',
    optimizer='sgd',
    metrics=['accuracy']
)

# %%
trainRes = model.fit(
    X_train, y_train, 
    batch_size=10, 
    epochs=300, 
    validation_data=(X_test, y_test), 
    verbose=0
)

# %%
plt.plot(trainRes.history['loss'])
plt.plot(trainRes.history['val_loss'])
plt.ylim(0, 1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test lss'], loc='upper right')

print(
    "Best Accuracy", max(trainRes.history['val_accuracy'])
)
# Out:
# Best Accuracy 0.8769344091415405

# %%
from keras.regularizers import l2

model = Sequential()
model.add(Dense(16, input_dim = 32, activation = 'tanh'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(8, activation = 'tanh'))
model.add(Dense(4, activation = 'tanh'))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(
    loss = 'binary_crossentropy',
    optimizer = 'sgd',
    metrics = ['accuracy']
)

# %%
trainRes = model.fit(
    X_train, y_train, 
    batch_size = 10, 
    epochs = 300, 
    validation_data = (X_test, y_test), 
    verbose = 0
)

# %%
plt.plot(trainRes.history['loss'])
plt.plot(trainRes.history['val_loss'])
plt.ylim(0, 1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test lss'], loc='upper right')

# %%
from keras.regularizers import l2

model = Sequential()
# 실질적으로 노이즈는 학습하지 않게 만들어주며, 동시에 반응성도 같이 올력주는 역할 수행 (정규화 과정 !)
# 커널은 네트워크 가중치, 바이어스는 절편에 대한 가중치를 다룬다.
model.add(Dense(16, input_dim=32, activation='tanh', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='tanh'))
model.add(Dense(4, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    loss='binary_crossentropy',
    optimizer='sgd',
    metrics=['accuracy']
)

# %%
trainRes = model.fit(
    X_train, y_train, 
    batch_size=10, 
    epochs=300, 
    validation_data=(X_test, y_test), 
    verbose=0
)

# %%
plt.plot(trainRes.history['loss'])
plt.plot(trainRes.history['val_loss'])
plt.ylim(0, 1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test lss'], loc='upper right')


print(
    "Best Accuracy", max(trainRes.history['val_accuracy'])
)
# Out:
# Best Accuracy 0.8769344091415405

# %%
from sklearn.datasets import load_boston

boston = load_boston()

boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
X = boston.data
y = boston.target

print(X)
print(y)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# 평균이 0이고 표준편차가 1이 되도록 스케일링
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(scaler)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
print(X_train)
# Out:
# [[-0.20735619 -0.49997924  1.54801583 ...  1.2272573   0.42454294
#    3.10807269]
#  [-0.38886492  0.34677427 -0.58974728 ...  0.05696346  0.40185312
#   -0.66643035]
#  [-0.33573486 -0.49997924  1.54801583 ...  1.2272573   0.39846135
#    0.63936662]
#  ...
#  [-0.38450355 -0.49997924 -0.15303077 ... -0.30312696  0.39659002
#   -0.30284441]
#  [-0.37511786 -0.49997924 -0.59690657 ... -0.25811566  0.37588849
#    0.89967717]
#  [-0.38592298 -0.49997924 -1.00641779 ... -0.84326258  0.42454294
#    0.31822262]]

# %%
print(X_test)
# Out:
# [[-0.39454262 -0.49997924 -1.12239824 ... -0.70822867  0.17086147
#   -0.72160487]
#  [ 0.70419882 -0.49997924  1.00534187 ...  0.77714428  0.0648977
#   -0.41177872]
#  [-0.38890688 -0.49997924  0.4025299  ... -0.93328518  0.38758427
#   -0.27454978]
#  ...
#  [ 1.61285743 -0.49997924  1.00534187 ...  0.77714428  0.42454294
#    2.59876943]
#  [-0.34350332 -0.49997924 -0.1687812  ... -0.03305915  0.42454294
#   -1.11772962]
#  [-0.39902507 -0.49997924 -1.27417512 ...  0.10197476  0.39202867
#   -1.02294263]]

# %%
print(X_test.shape)
# Out:
# (152, 13)

# %%
model = Sequential()

model.add(Dense(16, input_dim=13, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))

model.compile(
    loss = 'mean_squared_error',
    optimizer='rmsprop'
)

trainRes = model.fit(
    X_train, y_train, batch_size=5, epochs=300, validation_data=(X_test, y_test), verbose=0
)

# %%
plt.plot(trainRes.history['loss'])
plt.plot(trainRes.history['val_loss'])
plt.ylim(0, 100)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test lss'], loc='upper right')


print(
    "Lowest Error on Training = ", min(trainRes.history['loss'])
)

print(
    "Lowest Error on Test = ", min(trainRes.history['val_loss'])
)
# Out:
# Lowest Error on Training =  5.146114826202393
# Lowest Error on Test =  15.404181480407715

# %%
import numpy as mp

np.random.seed(1)

# %%
from keras.layers import Dropout

# %%
model = Sequential()

model.add(Dense(16, input_dim=13, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))

model.compile(
    loss = 'mean_squared_error',
    optimizer='rmsprop'
)

trainRes = model.fit(
    X_train, y_train, batch_size=5, epochs=300, validation_data=(X_test, y_test), verbose=0
)

# %%
plt.plot(trainRes.history['loss'])
plt.plot(trainRes.history['val_loss'])
plt.ylim(0, 100)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test lss'], loc='upper right')


print(
    "Lowest Error on Training = ", min(trainRes.history['loss'])
)

print(
    "Lowest Error on Test = ", min(trainRes.history['val_loss'])
)

print("Test Loss = ", model.evaluate(X_test, y_test))
# Out:
# Lowest Error on Training =  11.754509925842285
# Lowest Error on Test =  26.489526748657227
# 5/5 [==============================] - 0s 439us/step - loss: 41.0696
# Test Loss =  41.069576263427734

# %%
model = Sequential()

model.add(Dense(16, input_dim=13, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(
    loss = 'mean_squared_error',
    optimizer='rmsprop'
)

trainRes = model.fit(
    X_train, y_train, batch_size=5, epochs=300, validation_data=(X_test, y_test), verbose=0
)

# %%
plt.plot(trainRes.history['loss'])
plt.plot(trainRes.history['val_loss'])
plt.ylim(0, 100)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test lss'], loc='upper right')


print(
    "Lowest Error on Training = ", min(trainRes.history['loss'])
)

print(
    "Lowest Error on Test = ", min(trainRes.history['val_loss'])
)

print("Test Loss = ", model.evaluate(X_test, y_test))
# Out:
# Lowest Error on Training =  28.202716827392578
# Lowest Error on Test =  24.17194938659668
# 5/5 [==============================] - 0s 461us/step - loss: 26.1360
# Test Loss =  26.136037826538086

# %%
from sklearn.datasets import make_classification

X, y = make_classification(
    n_samples=400,
    n_features=10,
    n_classes=2
)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
model = Sequential()

model.add(Dense(16, input_dim=10, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    loss = 'binary_crossentropy',
    optimizer='rmsprop'
)

trainRes = model.fit(
    X_train, y_train, 
    batch_size=5, 
    epochs=300, 
    verbose=0
)

# %%
print("Test Loss = ", model.evaluate(X_test, y_test))
# Out:
# 4/4 [==============================] - 0s 583us/step - loss: 0.9040
# Test Loss =  0.9039525389671326

# %%
model = Sequential()

model.add(Dense(16, input_dim=10, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    loss = 'binary_crossentropy',
    optimizer='rmsprop'
)

trainRes = model.fit(
    X_train, y_train, 
    batch_size=5, 
    epochs=300, 
    verbose=0
)

# %%
print("Test Loss = ", model.evaluate(X_test, y_test))
# Out:
# 4/4 [==============================] - 0s 567us/step - loss: 0.1009
# Test Loss =  0.1008630245923996

# %%
model = Sequential()

model.add(Dense(16, input_dim=10, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(4, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    loss = 'binary_crossentropy',
    optimizer='rmsprop'
)

trainRes = model.fit(
    X_train, y_train, 
    batch_size=5, 
    epochs=300, 
    verbose=0
)


print("Test Loss = ", model.evaluate(X_test, y_test))
# Out:
# 4/4 [==============================] - 0s 580us/step - loss: 0.1179
# Test Loss =  0.1179114356637001

# %%
# l2는 오차에 대한 에러율을 낮추는데 활용한다
# 오차의 제곱을 가지고 연산하므로 잘못된 정보를 판단할 가능성 자체가 적다
# 특히 음수와 양수 형태로 구성된 오차간에 정보 오판율은 굉장히 낮다.
# 하지만 l2의 단점이라면 분산값이 굉장히 커질 수 있다.
# 분산이 커지는 것이 싫다면 l1_l2를 사용하도록 한다.

# Dropout은 잡음에 대한 정보 학습하는 과적합을 해결하기 위한 녀석
# 그러므로 일정 수치 이하의 정보에 대해서는 걸러내도록 만든다.
# 이 수치를 너무 크게 줄 경우 실제 정보도 같이 증발되므로 
#  적당한 수치값을 찾아내는 것이 중요하다.

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %%
X, y, = make_classification(
    n_samples=500,
    
    # 독립변수
    n_features=16,
    
    # 종속 변수
    n_classes=2
)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.3, random_state = 0
)

# %%
print(X.shape)
# Out:
# (500, 16)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
model = Sequential()

model.add(Dense(16, activation='relu', input_dim=16))
model.add(Dense(8, activation='relu')) # 0 ~ 1
model.add(Dense(4, activation='tanh')) # -1 ~ 1
model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer = 'sgd',
    loss = 'binary_crossentropy'
)

trainRes = model.fit(
    X_train, y_train,
    validation_data = (X_test, y_test),
    epochs = 400,
    batch_size = 5,
    verbose = 0
)

# %%
plt.plot(trainRes.history['loss'])
plt.plot(trainRes.history['val_loss'])
plt.ylim(0, 1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test lss'], loc='upper right')

# %%
# 훈련을 많이 했더는 훈련 로스는 없다.
# 그런데 테스트 로스가 높이진다? >> 결국 과적합이 되어 노이즈 정보까지 처리를 하는 상황

# 해결책
# 1. 훈련 수를 줄이면된다.(EarlyStopping)
# 2. l2를 사용해서 오차의 제곱의 합을 가지고 연산한다. >> 오차가 양수(+), 음수(-)로 인해 잘못된 판정을 할 수 있다.
#    그러므로 양쪽 모두 양수가 될 수 있는 제곱 형태를 취함
# 3. Dropout은 일정 확률 이하의 정보를 폐기처분

# %%
from keras.callbacks import EarlyStopping

# %%
model = Sequential()

model.add(Dense(16, activation='relu', input_dim=16))
model.add(Dense(8, activation='relu')) # 0 ~ 1
model.add(Dense(4, activation='tanh')) # -1 ~ 1
model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer = 'sgd',
    loss = 'binary_crossentropy'
)

# EarlyStopping을 사용한다면 fit을 하기 이전에 어디서 중단할 지를 정해야 한다.
es_callback = EarlyStopping(
    # val_loss: 테스트 로스를 감독함
    monitor='val_loss',
    
    # mode = 'min'은 최소값을 감지함
    mode='min'
)
# 콜백이란? 일종의 이벤트 
# 몰컴

trainRes = model.fit(
    X_train, y_train,
    validation_data = (X_test, y_test),
    epochs = 400,
    batch_size = 5,
    
    # 조건이 만족되면 콜백에 의해 fit이 중단되도록 구성한 부분
    callbacks = [es_callback],
    verbose = 0
)

print("Test loss = ", model.evaluate(X_test, y_test))
# Out:
# 5/5 [==============================] - 0s 587us/step - loss: 0.2174
# Test loss =  0.21744497120380402

# %%
plt.plot(trainRes.history['loss'])
plt.plot(trainRes.history['val_loss'])
plt.ylim(0, 1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test lss'], loc='upper right')

# %%
from keras.layers import GaussianNoise

# %%
model = Sequential()

model.add(Dense(16, input_dim=16, activation='tanh'))
model.add(GaussianNoise(0.1))
model.add(Dropout(0.5))
model.add(Dense(8, activation='tanh'))
model.add(GaussianNoise(0.1))
model.add(Dropout(0.1))
model.add(Dense(4, activation='tanh'))
model.add(GaussianNoise(0.1))
model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    loss = 'binary_crossentropy',
    optimizer='sgd'
)

trainRes = model.fit(
    X_train, y_train, 
    validation_data = (X_test, y_test),
    batch_size=5, 
    epochs=400, 
    verbose=0
)


print("Test Loss = ", model.evaluate(X_test, y_test))
# Out:
# 5/5 [==============================] - 0s 622us/step - loss: 0.2284
# Test Loss =  0.2284337878227234

# %%
print(trainRes.history)
# Out:
# {'loss': [0.7517549991607666, 0.6745988726615906, 0.619663417339325, 0.6074584722518921, 0.5735980272293091, 0.49181216955184937, 0.4746580719947815, 0.4415546655654907, 0.3928213119506836, 0.39719295501708984, 0.34344953298568726, 0.34227725863456726, 0.32518553733825684, 0.31265708804130554, 0.2964707911014557, 0.31231245398521423, 0.28045064210891724, 0.27769359946250916, 0.3117533028125763, 0.26023486256599426, 0.26141443848609924, 0.2632574141025543, 0.25460633635520935, 0.25592947006225586, 0.22139795124530792, 0.23684103786945343, 0.23311719298362732, 0.22190658748149872, 0.21810239553451538, 0.1859007626771927, 0.2184988409280777, 0.220167338848114, 0.24041126668453217, 0.22973652184009552, 0.22699350118637085, 0.20604442059993744, 0.2367260754108429, 0.24122346937656403, 0.21682842075824738, 0.2225494384765625, 0.1984422504901886, 0.21937386691570282, 0.18906478583812714, 0.20665505528450012, 0.21035204827785492, 0.18971729278564453, 0.22603653371334076, 0.22345182299613953,
# ...

# %%
plt.plot(trainRes.history['loss'])
plt.plot(trainRes.history['val_loss'])
plt.ylim(0, 1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test loss'], loc='upper right')

# %%
# !ls
# Out:
# Applied-Deep-Learning-with-Keras  fourth.ipynb	    seventh.ipynb
# data				  LICENSE	    sixth.ipynb
# eighth.ipynb			  nineth.ipynb	    Task
# eleventh.ipynb			  numba_exam.ipynb  tenth.ipynb
# fifth.ipynb			  README.md	    third.ipynb
# first.ipynb			  second.ipynb	    tweleveth.ipynb

# %%
import pandas as pd

# %%
nadm = pd.read_csv(
    "Applied-Deep-Learning-with-Keras/Lesson06/data/Flu.csv",
    index_col = 0
)

nadm.head()
# Out:
#             diagnosis
# patient id
# 1001                1
# 1002                1
# 1003                1
# 1004                0
# 1005                1

# %%
# 데이터에 1과 0이 몇개인지 count
nadm.diagnosis.value_counts()
# Out:
# 1    96
# 0     4
# Name: diagnosis, dtype: int64

# %%
nadm.diagnosis.value_counts().head(1) / len(nadm.diagnosis)
# Out:
# 1    0.96
# Name: diagnosis, dtype: float64
